# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime 
import matplotlib.dates as md

# %%
df=pd.read_csv('pollution.csv')
df.head()
# Out:
#          created_at  entry_id  Ghadi Chowk      Mowa    Pandri
# 0  17-04-2024 07:59    167601     2.562637  3.015531  2.758462
# 1  17-04-2024 08:00    167602     2.565861  3.016337  2.761685
# 2  17-04-2024 08:00    167603     2.569890  3.019560  2.764103
# 3  17-04-2024 08:01    167604     2.573114  3.019560  2.766520
# 4  17-04-2024 08:02    167605     2.576337  3.019560  2.768132

# %%
df.drop("entry_id",axis=1,inplace=True)
df.head()
# Out:
#          created_at  Ghadi Chowk      Mowa    Pandri
# 0  17-04-2024 07:59     2.562637  3.015531  2.758462
# 1  17-04-2024 08:00     2.565861  3.016337  2.761685
# 2  17-04-2024 08:00     2.569890  3.019560  2.764103
# 3  17-04-2024 08:01     2.573114  3.019560  2.766520
# 4  17-04-2024 08:02     2.576337  3.019560  2.768132

# %%
 #finding out the time when max. pollution occurs at Ghadi Chowk
df[df['Ghadi Chowk']==3.0235897439999997].drop(['Pandri','Mowa'],axis=1)
# Out:
# Empty DataFrame
# Columns: [created_at, Ghadi Chowk]
# Index: []

# %%
 #finding out the time when max. pollution occurs at Pandri
df[df['Pandri']==3.0235897439999997].drop(['Ghadi Chowk','Mowa'],axis=1)
# Out:
# Empty DataFrame
# Columns: [created_at, Pandri]
# Index: []

# %%
 #finding out the time when max. pollution occurs at Mowa
df[df['Mowa']==3.0235897439999997].drop(['Ghadi Chowk','Pandri'],axis=1)
# Out:
# Empty DataFrame
# Columns: [created_at, Mowa]
# Index: []

# %%
#finding out pollution level at Ghadi Chowk by hourly update
plt.figure(figsize=(12,8))
plt.rcParams.update({'font.size':15})
x =pd.to_datetime(df['created_at'], dayfirst=True)
y=df['Ghadi Chowk']
plt.plot_date(x, y)
plt.xlabel("Data & Hour")
plt.ylabel("Pollution Level")
plt.title("Hourly Pollution Level at Ghadi Chowk")
# Out:
# Text(0.5, 1.0, 'Hourly Pollution Level at Ghadi Chowk')

# %%
#finding out pollution level at Pandri by hourly update
plt.figure(figsize=(12,8))
plt.rcParams.update({'font.size':15})
x =pd.to_datetime(df['created_at'], dayfirst=True)
y=df['Pandri']
plt.plot_date(x, y,color='green')
plt.xlabel("Data & Hour")
plt.ylabel("Pollution Level")
plt.title("Hourly Pollution Level at Pandri")
# Out:
# Text(0.5, 1.0, 'Hourly Pollution Level at Pandri')

# %%
#finding out pollution level at Mowa by hourly update
plt.figure(figsize=(12,8))
plt.rcParams.update({'font.size':15})
x =pd.to_datetime(df['created_at'], dayfirst=True)
y=df['Mowa']
plt.plot_date(x, y,color='red')
plt.xlabel("Data & Hour")
plt.ylabel("Pollution Level")
plt.title("Hourly Pollution Level at Mowa")
# Out:
# Text(0.5, 1.0, 'Hourly Pollution Level at Mowa')

# %%
#pairplotting
sns.set(font_scale=1.5)
g=sns.pairplot(df,hue="Ghadi Chowk")
g.fig.set_size_inches(15,15)

# %%
sns.jointplot(x="Ghadi Chowk",y="Pandri",data=df,color='green')

# %%
sns.jointplot(x="Ghadi Chowk",y="Mowa",data=df,color='red')

# %%
sns.jointplot(x="Mowa",y="Pandri",data=df,color='k')
